# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('Mall_Customers.csv')

# %%
x=dataset.iloc[:, 3:5].values

# %%
from sklearn.cluster import OPTICS
OP=OPTICS(min_samples=2)
y_OP=OP.fit_predict(x)
# Out:
# C:\Users\jagadeesh\Anaconda3\lib\site-packages\sklearn\cluster\optics_.py:791: RuntimeWarning: divide by zero encountered in true_divide
#   ratio = reachability_plot[:-1] / reachability_plot[1:]

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['Cluster_group']=y_OP

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],fit_reg=False,legend=True,legend_out=True)
